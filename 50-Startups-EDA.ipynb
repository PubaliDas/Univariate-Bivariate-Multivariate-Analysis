# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("../demo/50_Startups.csv")

# %%
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#         RND      ADMIN        MKT       STATE    PROFIT
# 45  1000.23  124153.04    1903.93    New York  64926.08
# 46  1315.46  115816.21  297114.46     Florida  49490.75
# 47     0.00  135426.92       0.00  California  42559.73
# 48   542.05   51743.15       0.00    New York  35673.41
# 49     0.00  116983.80   45173.06  California  14681.40

# %%
df.sample(5)
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 40   28754.33  118546.05  172795.67  California   78239.91
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 37   44069.95   51283.14  197029.42  California   89949.14
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 46    1315.46  115816.21  297114.46     Florida   49490.75

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# RND       50 non-null float64
# ADMIN     50 non-null float64
# MKT       50 non-null float64
# STATE     50 non-null object
# PROFIT    50 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.0+ KB

# %%
df.dtypes
# Out:
# RND       float64
# ADMIN     float64
# MKT       float64
# STATE      object
# PROFIT    float64
# dtype: object

# %%
df.describe()
# Out:
#                  RND          ADMIN            MKT         PROFIT
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
df.describe(include='all')
# Out:
#                   RND          ADMIN            MKT     STATE         PROFIT
# count       50.000000      50.000000      50.000000        50      50.000000
# unique            NaN            NaN            NaN         3            NaN
# top               NaN            NaN            NaN  New York            NaN
# freq              NaN            NaN            NaN        17            NaN
# mean     73721.615600  121344.639600  211025.097800       NaN  112012.639200
# std      45902.256482   28017.802755  122290.310726       NaN   40306.180338
# min          0.000000   51283.140000       0.000000       NaN   14681.400000
# 25%      39936.370000  103730.875000  129300.132500       NaN   90138.902500
# 50%      73051.080000  122699.795000  212716.240000       NaN  107978.190000
# 75%     101602.800000  144842.180000  299469.085000       NaN  139765.977500
# max     165349.200000  182645.560000  471784.100000       NaN  192261.830000

# %%
df.nunique()
# Out:
# RND       49
# ADMIN     50
# MKT       48
# STATE      3
# PROFIT    50
# dtype: int64

# %%
df.STATE.unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df["STATE"].value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: STATE, dtype: int64

# %%
df.isnull().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df.mean()
# Out:
# RND        73721.6156
# ADMIN     121344.6396
# MKT       211025.0978
# PROFIT    112012.6392
# dtype: float64

# %%
df.PROFIT.mean()
# Out:
# 112012.63920000002

# %%
df.median()
# Out:
# RND        73051.080
# ADMIN     122699.795
# MKT       212716.240
# PROFIT    107978.190
# dtype: float64

# %%
df.PROFIT.median()
# Out:
# 107978.19

# %% [markdown]
# Univariate analysis

# %% [markdown]
# Bar Charts:

# %%
df['STATE'].value_counts().plot.bar(title="Freq dist of RND")

# %% [markdown]
# Histograms:

# %%
df.STATE.hist()
plt.plot()
# Out:
# []

# %%
df.RND.hist()
plt.plot()
# Out:
# []

# %%
df.MKT.hist()
plt.plot()
# Out:
# []

# %%
df.ADMIN.hist()
plt.plot()
# Out:
# []

# %%
df.PROFIT.hist()
plt.plot()
# Out:
# []

# %% [markdown]
# To cummulatively see the histograms:

# %%
col_names = ['RND','ADMIN','MKT','PROFIT']
fig=plt.figure(figsize=(18, 16))
fig, ax = plt.subplots(len(col_names), figsize=(16,12))

for i, col_val in enumerate(col_names):
        
    sns.distplot(df[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)
    
plt.show()

# %% [markdown]
# Count Plots for Categorical values:

# %%
sns.countplot(df.STATE) # categorical

# %% [markdown]
# Kernel Density Plots:

# %%
sns.kdeplot(df.RND, shade=True);

# %%
sns.kdeplot(df.ADMIN, shade=True);

# %% [markdown]
# Univariate outlier detection using Boxplots

# %%
col_names = ['RND','ADMIN','MKT','PROFIT']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):
        
    sns.boxplot(y=df[col_val], ax=ax[i])
    ax[i].set_title('Box plot - '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    
plt.show()

# %% [markdown]
# Bivariate plots

# %% [markdown]
# Scatter Plots:

# %%
plt.scatter(df.RND , df.PROFIT)
plt.xlabel("RND")
plt.ylabel("PROFIT")
plt.show()

# %%
plt.scatter(df.MKT , df.ADMIN)
plt.xlabel("MKT")
plt.ylabel("ADMIN")
plt.show()

# %%
plt.scatter(df.STATE , df.PROFIT)
plt.xlabel("STATE")
plt.ylabel("PROFIT")
plt.show()

# %% [markdown]
# Distribution Plots:

# %%
sns.FacetGrid(df,hue="STATE", size=5).map(sns.distplot,"PROFIT").add_legend()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Voilin plot:

# %%
sns.violinplot(x="STATE",y="PROFIT",data=df)

# %%
sns.violinplot(x="STATE",y="ADMIN",data=df)

# %% [markdown]
# Boxplots:

# %%
sns.boxplot(x="STATE",y="PROFIT",data=df)

# %%
sns.boxplot(x="STATE",y="RND",data=df)

# %% [markdown]
# Joint Plots:

# %%
sns.jointplot('RND', 'PROFIT', data = df, kind='scatter')

# %%
sns.jointplot("MKT", "ADMIN", data=df, kind='reg')

# %% [markdown]
# Hexbin Plots:

# %%
with sns.axes_style("white"):
    sns.jointplot(x="RND", y="PROFIT", data=df, kind="hex", color="k")

# %% [markdown]
# Kernel Density Estimation:

# %%
sns.jointplot(x="RND", y="PROFIT", data=df, kind="kde")

# %% [markdown]
# Multivariate analysis

# %% [markdown]
# Pair Plots:

# %%
sns.pairplot(df)

# %%
#To view the pairplots State wise
sns.pairplot(df, hue="STATE")

# %%
df.corr()
# Out:
#              RND     ADMIN       MKT    PROFIT
# RND     1.000000  0.241955  0.724248  0.972900
# ADMIN   0.241955  1.000000 -0.032154  0.200717
# MKT     0.724248 -0.032154  1.000000  0.747766
# PROFIT  0.972900  0.200717  0.747766  1.000000

# %%
print(df.corr()['PROFIT'].sort_values(ascending = False),'\n')
# Out:
# PROFIT    1.000000
# RND       0.972900
# MKT       0.747766
# ADMIN     0.200717
# Name: PROFIT, dtype: float64

# %% [markdown]
# Heat Maps

# %%
sns.heatmap(df.corr())

# %% [markdown]
# Scatter Plots for Multivariate Analysis:

# %%
sns.lmplot(x='RND',y="PROFIT",data=df,hue='STATE',fit_reg=False)
plt.show()

# %%
sns.lmplot(x='MKT',y="PROFIT",data=df,hue='STATE',fit_reg=False)
plt.show()
